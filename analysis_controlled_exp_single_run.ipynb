# %%
import pandas as pd
import re
import os
import matplotlib.pyplot as plt
from IPython.display import display
import warnings
warnings.simplefilter('always')

from scripts.a_data_loading_cleaning import run_load_clean_diagnose_data

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# To do
# - [ ] segment all of this by model -> run the whole process separately by creating separate dfs per model
# - [ ] aggregate multiple runs correctly: identify unique configs, then take mean across all configs, plot mean and each version of the config (but visually distinct), and plot scatter plot, where the mean is c of all results metrics for tha

# %% [markdown]
# # Data Loading & Cleaning

# %%
csv_path = "results/controlled_results.csv"
df = run_load_clean_diagnose_data(csv_path)
# Out:
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/site-packages/executing/executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/site-packages/executing/executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/ast.py:587: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#   return Constant(*args, **kwargs)
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/site-packages/executing/executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/ast.py:587: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#   return Constant(*args, **kwargs)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 csv_path = "results/controlled_results_16_04.csv"
# ----> 2 df = run_load_clean_diagnose_data(csv_path)
#
# File ~/repositories/thesis_analysis/scripts/a_data_loading_cleaning.py:565, in run_load_clean_diagnose_data(csv_path)
#     563 def run_load_clean_diagnose_data(csv_path: str = "results/controlled_results.csv") -> pd.DataFrame:
#     564     # Load and clean data
# --> 565     df = load_and_clean_data(csv_path)
#     566     df = create_derived_columns(df)
#     567     df = filter_by_dominant_token_count(df)
#
# File ~/repositories/thesis_analysis/scripts/a_data_loading_cleaning.py:244, in load_and_clean_data(csv_path)
#     240 def load_and_clean_data(csv_path: str) -> pd.DataFrame:
#     241     """
#     242     Loads a CSV from csv_path and cleans the column names and order.
#     243     """
# --> 244     df = pd.read_csv(csv_path)
#     245     df_cleaned = clean_and_reorder_columns(df, desired_order)
#     246     return df_cleaned
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/controlled_results_16_04.csv'

# %%
cols_to_describe = [
    'total_energy_kwh',
    'total_inference_time_sec',
    'average_latency_ms_per_batch',
    'throughput_queries_per_sec',
    'throughput_tokens_per_sec',
    'cpu_energy_total',
    'gpu_energy_total',
    'flops_per_token',
    'energy_per_token_kwh',
    'divergence_energy_flops'
]

df[cols_to_describe].describe()
# Out:
#        total_energy_kwh  total_inference_time_sec  \
# count         88.000000                 88.000000
# mean           0.021104                 38.438732
# std            0.005771                 13.666694
# min            0.003973                  9.628563
# 25%            0.021053                 36.740853
# 50%            0.021162                 37.063840
# 75%            0.021235                 37.338340
# max            0.064102                147.516985
#
#        average_latency_ms_per_batch  throughput_queries_per_sec  \
# count                     88.000000                   88.000000
# mean                    4662.541943                    3.573381
# std                      558.983884                    1.217770
# min                     2868.194596                    0.867697
# 25%                     4593.879790                    3.428112
# 50%                     4633.730808                    3.453501
# 75%                     4667.292441                    3.483860
# max                     9029.341061                   13.293780
#
#        throughput_tokens_per_sec  cpu_energy_total  gpu_energy_total  \
# count                  88.000000         88.000000         88.000000
# mean                  457.392832          0.004661          0.016412
# std                   155.874513          0.001752          0.004104
# min                   111.065177          0.001194          0.002724
# 25%                   438.798308          0.004547          0.016461
# 50%                   442.048106          0.004574          0.016542
# 75%                   445.934128          0.004598          0.016604
# max                  1701.603812          0.018196          0.045785
#
#        flops_per_token  energy_per_token_kwh  divergence_energy_flops
# count     8.800000e+01          8.800000e+01             8.800000e+01
# mean      1.034544e+09          1.288077e-06             1.245067e-15
# std       0.000000e+00          3.522471e-07             3.404853e-16
# min       1.034544e+09          2.425090e-07             2.344114e-16
# 25%       1.034544e+09          1.284950e-06             1.242045e-15
# 50%       1.034544e+09          1.291647e-06             1.248518e-15
# 75%       1.034544e+09          1.296080e-06             1.252803e-15
# max       1.034544e+09          3.912481e-06             3.781841e-15

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
from scripts.b_exploratory_data_analysis import (
    plot_histogram,
    plot_boxplot,
    plot_scatter,
    plot_divergence,
    plot_correlation_matrix,
    plot_all_diagnostics
)

plot_all_diagnostics(df)
# Out:
# 📊 Plotting histogram...
# 📦 Plotting boxplot...
# /Users/henrybaker/repositories/thesis_analysis/scripts/b_exploratory_data_analysis.py:28: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(data[column].dropna(), vert=False)
# 🔬 Scatter: Energy vs FLOPs...
# 📈 Scatter: Divergence vs Batch Size...
# 🔗 Correlation matrix...

# %% [markdown]
# To do:
# - [ ] crop outliers temporarily -> look at closer grouped in more detail
# - [ ] examine the divergence plot more

# %% [markdown]
# # Controlled Experiment Visualisation

# %%
df['config_name'].unique()
# Out:
# array(['num_processes_1', 'num_processes_2', 'num_processes_3',
#        'num_processes_4', 'batching_4', 'batching_8', 'batching_16',
#        'batching_32', 'batching_64',
#        'precis_float32_quant_False_quant8_False_quant4_False',
#        'precis_float16_quant_False_quant8_False_quant4_False',
#        'precis_float16_quant_True_quant8_True_quant4_False',
#        'precis_float16_quant_True_quant8_False_quant4_True',
#        'decoding_greedy_decoder_temperature_0',
#        'decoding_greedy_decoder_temperature_0.2',
#        'decoding_greedy_decoder_temperature_0.4',
#        'decoding_greedy_decoder_temperature_0.6',
#        'decoding_greedy_decoder_temperature_0.8',
#        'decoding_greedy_decoder_temperature_1.0',
#        'decoding_greedy_decoder_temperature_1.2',
#        'decoding_top_k_decoder_top_k_20_decoder_temperature_0',
#        'decoding_top_k_decoder_top_k_50_decoder_temperature_0',
#        'decoding_top_k_decoder_top_k_100_decoder_temperature_0',
#        'decoding_top_k_decoder_top_k_200_decoder_temperature_0',
#        'decoding_top_k_decoder_top_k_500_decoder_temperature_0',
#        'decoding_top_k_decoder_top_k_20_decoder_temperature_0.2',
#        'decoding_top_k_decoder_top_k_50_decoder_temperature_0.2',
#        'decoding_top_k_decoder_top_k_100_decoder_temperature_0.2',
#        'decoding_top_k_decoder_top_k_200_decoder_temperature_0.2',
#        'decoding_top_k_decoder_top_k_500_decoder_temperature_0.2',
#        'decoding_top_k_decoder_top_k_20_decoder_temperature_0.4',
#        'decoding_top_k_decoder_top_k_50_decoder_temperature_0.4',
#        'decoding_top_k_decoder_top_k_100_decoder_temperature_0.4',
#        'decoding_top_k_decoder_top_k_200_decoder_temperature_0.4',
#        'decoding_top_k_decoder_top_k_500_decoder_temperature_0.4',
#        'decoding_top_k_decoder_top_k_20_decoder_temperature_0.6',
#        'decoding_top_k_decoder_top_k_50_decoder_temperature_0.6',
#        'decoding_top_k_decoder_top_k_100_decoder_temperature_0.6',
#        'decoding_top_k_decoder_top_k_200_decoder_temperature_0.6',
#        'decoding_top_k_decoder_top_k_500_decoder_temperature_0.6',
#        'decoding_top_k_decoder_top_k_20_decoder_temperature_0.8',
#        'decoding_top_k_decoder_top_k_50_decoder_temperature_0.8',
#        'decoding_top_k_decoder_top_k_100_decoder_temperature_0.8',
#        'decoding_top_k_decoder_top_k_200_decoder_temperature_0.8',
#        'decoding_top_k_decoder_top_k_500_decoder_temperature_0.8',
#        'decoding_top_k_decoder_top_k_20_decoder_temperature_1.0',
#        'decoding_top_k_decoder_top_k_50_decoder_temperature_1.0',
#        'decoding_top_k_decoder_top_k_100_decoder_temperature_1.0',
#        'decoding_top_k_decoder_top_k_200_decoder_temperature_1.0',
#        'decoding_top_k_decoder_top_k_500_decoder_temperature_1.0',
#        'decoding_top_k_decoder_top_k_20_decoder_temperature_1.2',
#        'decoding_top_k_decoder_top_k_50_decoder_temperature_1.2',
#        'decoding_top_k_decoder_top_k_100_decoder_temperature_1.2',
#        'decoding_top_k_decoder_top_k_200_decoder_temperature_1.2',
#        'decoding_top_k_decoder_top_k_500_decoder_temperature_1.2',
#        'decoding_top_p_decoder_top_p_0.7_decoder_temperature_0',
#        'decoding_top_p_decoder_top_p_0.8_decoder_temperature_0',
#        'decoding_top_p_decoder_top_p_0.9_decoder_temperature_0',
#        'decoding_top_p_decoder_top_p_0.98_decoder_temperature_0',
#        'decoding_top_p_decoder_top_p_0.7_decoder_temperature_0.2',
#        'decoding_top_p_decoder_top_p_0.8_decoder_temperature_0.2',
#        'decoding_top_p_decoder_top_p_0.9_decoder_temperature_0.2',
#        'decoding_top_p_decoder_top_p_0.98_decoder_temperature_0.2',
#        'decoding_top_p_decoder_top_p_0.7_decoder_temperature_0.4',
#        'decoding_top_p_decoder_top_p_0.8_decoder_temperature_0.4',
#        'decoding_top_p_decoder_top_p_0.9_decoder_temperature_0.4',
#        'decoding_top_p_decoder_top_p_0.98_decoder_temperature_0.4',
#        'decoding_top_p_decoder_top_p_0.7_decoder_temperature_0.6',
#        'decoding_top_p_decoder_top_p_0.8_decoder_temperature_0.6',
#        'decoding_top_p_decoder_top_p_0.9_decoder_temperature_0.6',
#        'decoding_top_p_decoder_top_p_0.98_decoder_temperature_0.6',
#        'decoding_top_p_decoder_top_p_0.7_decoder_temperature_0.8',
#        'decoding_top_p_decoder_top_p_0.8_decoder_temperature_0.8',
#        'decoding_top_p_decoder_top_p_0.9_decoder_temperature_0.8',
#        'decoding_top_p_decoder_top_p_0.98_decoder_temperature_0.8',
#        'decoding_top_p_decoder_top_p_0.7_decoder_temperature_1.0',
#        'decoding_top_p_decoder_top_p_0.8_decoder_temperature_1.0',
#        'decoding_top_p_decoder_top_p_0.9_decoder_temperature_1.0',
#        'decoding_top_p_decoder_top_p_0.98_decoder_temperature_1.0',
#        'decoding_top_p_decoder_top_p_0.7_decoder_temperature_1.2',
#        'decoding_top_p_decoder_top_p_0.8_decoder_temperature_1.2',
#        'decoding_top_p_decoder_top_p_0.9_decoder_temperature_1.2',
#        'decoding_top_p_decoder_top_p_0.98_decoder_temperature_1.2',
#        'latency_False',
#        'latency_True_latency_0.05_latency_0.2_latency_False',
#        'latency_True_latency_0.2_latency_0.6_latency_False',
#        'latency_True_latency_0.05_latency_0.2_latency_True_latency_4.0_latency_5',
#        'latency_True_latency_0.2_latency_0.6_latency_True_latency_5.0_latency_8'],
#       dtype=object)

# %%
from scripts.c_controlled_exp_visualisations_single_run import (
    plot_num_processes,
    plot_batching,
    plot_precision,
    plot_decoder_temperature,
    plot_decoder_topk_top_p,
    plot_latency,
    plot_latency_dynamic,
    plot_all_vizs,
)

import importlib
import scripts.c_controlled_exp_visualisations_single_run as viz
importlib.reload(viz)

configs = ['num_processes', 'batching','precis', 'decoding', 'latency']
dfs = {config: df[df['config_name'].str.startswith(config)] for config in configs}

plot_all_vizs(dfs)
# Out:
# /Users/henrybaker/repositories/thesis_analysis/scripts/c_controlled_exp_visualisations_single_run.py:468: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   energy_pivot = latency_df.pivot_table(
# /Users/henrybaker/repositories/thesis_analysis/scripts/c_controlled_exp_visualisations_single_run.py:474: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flops_pivot = latency_df.pivot_table(

# %% [markdown]
# to do:
# - [ ] don't treat no simulation and simulation as categorically distinct, rather they are on a continuous number line, and the plots should reflect that
# - [ ] get FLOPs to print just once, and the legend to only be taken from one axis
# - PRINT WITH NORMALISED AXIS!!!! - Plot the values as a percent of the mean to visualise their relative spread

# %% [markdown]
# TO DO: WORK OUT % OF TOTAL ENERGY CONSUMPTION / VARIANCE THAT CAN BE EXPLAINED BY TOTAL CONFIGS CHANGES VS BASELINE THAT IS MODEL DETERMINED

# %% [markdown]
# # Modeling

# %%
from scripts.d_base_regression import run_full_regression_analysis, preprocess_data

df = preprocess_data(df)

# With default predictors
run_full_regression_analysis(df)

# With custom predictors
custom_predictors = ["batch_size_numeric", "C(fp_precision)", "C(quantization)"]
run_full_regression_analysis(df, predictors=custom_predictors)
# Out:
# 📊 Running OLS regression for energy_per_token_kwh...
#
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     energy_per_token_kwh   R-squared:                       0.462
# Model:                              OLS   Adj. R-squared:                  0.436
# Method:                   Least Squares   F-statistic:                     17.80
# Date:                  Fri, 18 Apr 2025   Prob (F-statistic):           1.38e-10
# Time:                          19:38:32   Log-Likelihood:                 1210.5
# No. Observations:                    88   AIC:                            -2411.
# Df Residuals:                        83   BIC:                            -2399.
# Df Model:                             4
# Covariance Type:              nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -2.093e-07   3.98e-07     -0.526      0.600      -1e-06    5.82e-07
# C(fp_precision)[T.torch.float32]  5.089e-07   3.74e-07      1.360      0.177   -2.35e-07    1.25e-06
# C(quantization)[T.True]           5.516e-07   2.66e-07      2.072      0.041    2.22e-08    1.08e-06
# batch_size_numeric                -3.23e-08   5.05e-09     -6.397      0.000   -4.23e-08   -2.23e-08
# num_processes                     3.778e-07   7.18e-08      5.262      0.000    2.35e-07    5.21e-07
# ==============================================================================
# Omnibus:                      166.323   Durbin-Watson:                   1.514
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12932.611
# Skew:                           7.335   Prob(JB):                         0.00
# Kurtosis:                      60.549   Cond. No.                         329.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# 📊 Running OLS regression for divergence_energy_flops...
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     divergence_energy_flops   R-squared:                       0.462
# Model:                                 OLS   Adj. R-squared:                  0.436
# Method:                      Least Squares   F-statistic:                     17.80
# Date:                     Fri, 18 Apr 2025   Prob (F-statistic):           1.38e-10
# Time:                             19:38:32   Log-Likelihood:                 3037.1
# No. Observations:                       88   AIC:                            -6064.
# Df Residuals:                           83   BIC:                            -6052.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -2.024e-16   3.85e-16     -0.526      0.600   -9.67e-16    5.63e-16
# C(fp_precision)[T.torch.float32]  4.919e-16   3.62e-16      1.360      0.177   -2.27e-16    1.21e-15
# C(quantization)[T.True]           5.332e-16   2.57e-16      2.072      0.041    2.14e-17    1.04e-15
# batch_size_numeric               -3.123e-17   4.88e-18     -6.397      0.000   -4.09e-17   -2.15e-17
# num_processes                     3.652e-16   6.94e-17      5.262      0.000    2.27e-16    5.03e-16
# ==============================================================================
# Omnibus:                      166.323   Durbin-Watson:                   1.514
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12932.611
# Skew:                           7.335   Prob(JB):                         0.00
# Kurtosis:                      60.549   Cond. No.                         329.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# 📈 Plotting residuals for energy model...
# 📊 Running OLS regression for energy_per_token_kwh...
#
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     energy_per_token_kwh   R-squared:                       0.282
# Model:                              OLS   Adj. R-squared:                  0.257
# Method:                   Least Squares   F-statistic:                     11.01
# Date:                  Fri, 18 Apr 2025   Prob (F-statistic):           3.61e-06
# Time:                          19:38:32   Log-Likelihood:                 1197.8
# No. Observations:                    88   AIC:                            -2388.
# Df Residuals:                        84   BIC:                            -2378.
# Df Model:                             3
# Covariance Type:              nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                         1.295e-06   3.18e-07      4.079      0.000    6.64e-07    1.93e-06
# C(fp_precision)[T.torch.float32]  5.089e-07    4.3e-07      1.185      0.239   -3.45e-07    1.36e-06
# C(quantization)[T.True]            5.25e-07   3.05e-07      1.719      0.089   -8.25e-08    1.13e-06
# batch_size_numeric               -3.188e-08    5.8e-09     -5.500      0.000   -4.34e-08   -2.04e-08
# ==============================================================================
# Omnibus:                      120.120   Durbin-Watson:                   1.194
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4884.648
# Skew:                           4.238   Prob(JB):                         0.00
# Kurtosis:                      38.501   Cond. No.                         304.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# 📊 Running OLS regression for divergence_energy_flops...
#
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     divergence_energy_flops   R-squared:                       0.282
# Model:                                 OLS   Adj. R-squared:                  0.257
# Method:                      Least Squares   F-statistic:                     11.01
# Date:                     Fri, 18 Apr 2025   Prob (F-statistic):           3.61e-06
# Time:                             19:38:32   Log-Likelihood:                 3024.4
# No. Observations:                       88   AIC:                            -6041.
# Df Residuals:                           84   BIC:                            -6031.
# Df Model:                                3
# Covariance Type:                 nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                         1.252e-15   3.07e-16      4.079      0.000    6.42e-16    1.86e-15
# C(fp_precision)[T.torch.float32]  4.919e-16   4.15e-16      1.185      0.239   -3.34e-16    1.32e-15
# C(quantization)[T.True]           5.075e-16   2.95e-16      1.719      0.089   -7.97e-17    1.09e-15
# batch_size_numeric               -3.082e-17    5.6e-18     -5.500      0.000    -4.2e-17   -1.97e-17
# ==============================================================================
# Omnibus:                      120.120   Durbin-Watson:                   1.194
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4884.648
# Skew:                           4.238   Prob(JB):                         0.00
# Kurtosis:                      38.501   Cond. No.                         304.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# 📈 Plotting residuals for energy model...

# %%
# %run scripts/d_mixed_effects_model.py
# Out:
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/site-packages/executing/executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/site-packages/executing/executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/ast.py:587: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#   return Constant(*args, **kwargs)
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/site-packages/executing/executing.py:713: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   right=ast.Str(s=sentinel),
# /Users/henrybaker/miniconda3/envs/thesis/lib/python3.12/ast.py:587: DeprecationWarning: Attribute s is deprecated and will be removed in Python 3.14; use value instead
#   return Constant(*args, **kwargs)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'scripts/d_mixed_effects_model.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('run', 'scripts/d_mixed_effects_model.py')
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/envs/thesis/lib/python3.12/site-packages/IPython/core/magics/execution.py:731, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     729     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     730         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 731     raise Exception(msg) from e
#     732 except TypeError:
#     733     if fpath in sys.meta_path:
#
# Exception: File `'scripts/d_mixed_effects_model.py'` not found.

# %%
df['energy_per_token_kwh'].max() -  df['energy_per_token_kwh'].min()

# %% [markdown]
# To do
# - [ ] identify groupings:
#    - [ ] use model (even though currently only one model)
#    - [ ] use config_name and date_time
#    - [ ] use decoder configs
#    - [ ] latency configs
